# %% [markdown]
# # 03 — ETL Pipeline

# %%
from pathlib import Path
import os
from dotenv import load_dotenv

#  pip install python-dotenv

load_dotenv()

connections = os.getenv("DATABASE_URL")

print(connections)
